# %% [markdown]
# <a href="https://colab.research.google.com/github/Samirlamichhane10/movie_recommendation/blob/main/movie/movie_recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
cd /content/drive/My Drive/Colab Notebooks/movie
# Out:
# /content/drive/My Drive/Colab Notebooks/movie

# %%
movies = pd.read_csv('tmdb_5000_movies.csv')
credits = pd.read_csv('tmdb_5000_credits.csv')

# %%
movies= movies.merge(credits, on='title')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4809 non-null   int64
#  1   genres                4809 non-null   object
#  2   homepage              1713 non-null   object
#  3   id                    4809 non-null   int64
#  4   keywords              4809 non-null   object
#  5   original_language     4809 non-null   object
#  6   original_title        4809 non-null   object
#  7   overview              4806 non-null   object
#  8   popularity            4809 non-null   float64
#  9   production_companies  4809 non-null   object
#  10  production_countries  4809 non-null   object
#  11  release_date          4808 non-null   object
#  12  revenue               4809 non-null   int64
#  13  runtime               4807 non-null   float64
#  14  spoken_languages      4809 non-null   object
# ...

# %%
 movies1= movies[['movie_id','title','overview', 'genres', 'keywords', 'cast', 'crew']]

# %%
movies1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4809 non-null   int64
#  1   title     4809 non-null   object
#  2   overview  4806 non-null   object
#  3   genres    4809 non-null   object
#  4   keywords  4809 non-null   object
#  5   cast      4809 non-null   object
#  6   crew      4809 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 263.1+ KB

# %%
movies1.iloc[:4].genres
# Out:
# 0    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1    [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3    [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# Name: genres, dtype: object

# %%
import ast
def convert(obj):
    L = []
    for i in ast.literal_eval(obj):  # ast.literal_evals(obj) , it converts the string list into the list
        L.append(i['name'])
    return L

# %%
movies1['genres']=movies1['genres'].apply(convert)

# %%
movies1.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies1['keywords']= movies1['keywords'].apply(convert)

# %%
import ast
def top_casts(obj):
    L = []
    j=0
    for i in ast.literal_eval(obj):  # ast.literal_evals(obj) , it converts the string list into the list
        L.append(i['name'])
        j+=1
        if j==3: # cause we need only top 3 actors or casts
            break
    return L

# %%
movies1['cast']=movies1['cast'].apply(top_casts)

# %%
movies1['crew'][0]
# Out:
# '[{"credit_id": "52fe48009251416c750aca23", "department": "Editing", "gender": 0, "id": 1721, "job": "Editor", "name": "Stephen E. Rivkin"}, {"credit_id": "539c47ecc3a36810e3001f87", "department": "Art", "gender": 2, "id": 496, "job": "Production Design", "name": "Rick Carter"}, {"credit_id": "54491c89c3a3680fb4001cf7", "department": "Sound", "gender": 0, "id": 900, "job": "Sound Designer", "name": "Christopher Boyes"}, {"credit_id": "54491cb70e0a267480001bd0", "department": "Sound", "gender": 0, "id": 900, "job": "Supervising Sound Editor", "name": "Christopher Boyes"}, {"credit_id": "539c4a4cc3a36810c9002101", "department": "Production", "gender": 1, "id": 1262, "job": "Casting", "name": "Mali Finn"}, {"credit_id": "5544ee3b925141499f0008fc", "department": "Sound", "gender": 2, "id": 1729, "job": "Original Music Composer", "name": "James Horner"}, {"credit_id": "52fe48009251416c750ac9c3", "department": "Directing", "gender": 2, "id": 2710, "job": "Director", "name": "James Cameron"
# ...

# %%
def crew_director(obj):
    L = []

    for i in ast.literal_eval(obj):  # ast.literal_evals(obj) , it converts the string list into the list
        if i['job']=='Director':
            L.append(i['name'])
            break
    return L

# %%
movies1['crew']=movies1['crew'].apply(crew_director)

# %%
movies1.sample(5)
# Out:
#       movie_id                title  \
# 2238     46435          Topsy-Turvy
# 2041    205588  Our Kind of Traitor
# 648      11820      Mona Lisa Smile
# 1311      1957               Enough
# 3333      2011           Persepolis
#
#                                                overview  \
# 2238  After their production "Princess Ida" meets wi...
# 2041  A young Oxford academic and his attorney girlf...
# 648   The story of Katherine Ann Watson, a feminist ...
# 1311  Working-class waitress Slim thought she was en...
# 3333  In 1970s Iran, Marjane 'Marji' Statrapi watche...
#
#                       genres  \
# 2238  [Comedy, Drama, Music]
# 2041              [Thriller]
# 648         [Drama, Romance]
# 1311       [Drama, Thriller]
# 3333      [Animation, Drama]
#
#                                                keywords  \
# 2238  [prostitute, musical, biography, telephone cal...
# 2041                   [based on novel, woman director]
# ...

# %%
movies1['crew']=movies1['crew'].apply(lambda x:[i.replace(" ","") for i in x])
movies1['cast']=movies1['cast'].apply(lambda x:[i.replace(" ","") for i in x]) ## removing the whitespace between name
movies1['keywords']=movies1['keywords'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
movies1['overview'].isnull().sum()
movies1['overview']=movies1['overview'].fillna('')
movies1['overview']= movies1['overview'].apply(lambda x:x.split())

# %%
movies1.sample(5)
# Out:
#       movie_id                              title  \
# 1232    188161  A Million Ways to Die in the West
# 4148     11302                            Bananas
# 3770      1809            The Rules of Attraction
# 1543      8012                         Get Shorty
# 3886     22051                               Adam
#
#                                                overview  \
# 1232  [As, a, cowardly, farmer, begins, to, fall, fo...
# 4148  [When, a, bumbling, New, Yorker, is, dumped, b...
# 3770  [The, incredibly, spoiled, and, overprivileged...
# 1543  [Chili, Palmer, is, a, Miami, mobster, who, ge...
# 3886  [Adam,, a, lonely, man, with, Asperger's, Synd...
#
#                          genres  \
# 1232          [Comedy, Western]
# 4148                   [Comedy]
# 3770   [Comedy, Drama, Romance]
# 1543  [Comedy, Thriller, Crime]
# 3886           [Drama, Romance]
#
#                                                keywords  \
# 1232           [gunslinger, farmer, wildwest, laxative]
# ...

# %%
movies1['tags'] = movies1['overview']+movies1['genres']+movies1['keywords']+movies1['cast']+movies1['crew']

# %%
 movies1= movies1[['movie_id','title', 'tags']]

# %%
movies1['tags']= movies1['tags'].apply(lambda x: " ".join(x))

# %%
movies1.sample(5)
# Out:
#       movie_id                          title  \
# 3497     11583  The First Great Train Robbery
# 4763    174362                  Bending Steel
# 3294     12183        The Wendell Baker Story
# 4076    347548                    Containment
# 2261     19457                      The Yards
#
#                                                    tags
# 3497  In Victorian England, a master criminal makes ...
# 4763  The Cyclone, The Freakshow, The Mermaid Parade...
# 3294  Luke Wilson plays a good-hearted ex-con who ge...
# 4076  Neighbors in a block wake one morning to find ...
# 2261  In the rail yards of Queens, contractors repai...

# %%
import nltk    ## for tokenization and lemmatization

nltk.download('punkt')
nltk.download('wordnet')
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
word_tokenize(movies1['tags'][1955]) ## example of tokenization
# Out:
# ['Story',
#  'of',
#  'a',
#  'couple',
#  'that',
#  'starts',
#  'the',
#  'first',
#  'legal',
#  'brothel',
#  'in',
#  'Nevada',
#  'and',
#  'a',
#  'boxer',
#  'they',
#  'own',
#  'a',
#  'piece',
#  'of',
#  '.',
#  'Drama',
#  'independentfilm',
#  'HelenMirren',
#  'JoePesci',
#  'SergioPeris-Mencheta',
#  'TaylorHackford']

# %%
def tokenizer_lemmatizer(text):
  lemmatizer = WordNetLemmatizer()
  tokens= word_tokenize(text) # converts string into the list of tokens
  lemmatize_tokens= [lemmatizer.lemmatize(token) for token in tokens] ## lemmantizing inside the list of tokens ['loves', 'loved','loving']-->['love','love','love']
  return ' '.join(lemmatize_tokens) ## converting the list into the string

# %%
movies1['tags']=movies1['tags'].apply(tokenizer_lemmatizer)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000, stop_words='english', lowercase=True)
vector1= cv.fit_transform(movies1['tags'])## csr_matrix
vector = vector1.toarray() ## csr_matrix to array

# %%
len(cv.get_feature_names_out())#cv.vocabulary_.keys()
# Out:
# 5000

# %%
from sklearn.metrics.pairwise import cosine_similarity ## calculates the similarity of each movie with every other movie and returns an array (no_of_movies,_no_of_movies)
                                                         ## in this case (4806,4806)
similarity = cosine_similarity(vector)

similarity[1]
# Out:
# array([0.08471737, 1.        , 0.06154575, ..., 0.04875149, 0.        ,
#        0.02686077])

# %%
def recommend_movie(movie_title):
  movie_index= movies1[movies1['title']==movie_title].index[0]  ## returns the index of the movie
  similar_movie_data = similarity[movie_index]                  # returns the similarity value of movie with every movie 1 = highest similar value , 0 = lowest
  similar_movie_sorted=sorted(list(enumerate(similar_movie_data)), reverse= True,key=lambda x: x[1]) # Enumerate creates a list of tuples [(index, value),..] #key assists in printing the index of the movie
  for i in similar_movie_sorted[1:6]:                                                                # returns the top 5 similar movies
    print(movies1.iloc[i[0]].title)

# %%
recommend_movie("""Pirates of the Caribbean: At World's End""")
# Out:
# Pirates of the Caribbean: Dead Man's Chest
# Pirates of the Caribbean: On Stranger Tides
# Pirates of the Caribbean: The Curse of the Black Pearl
# The Pirates! In an Adventure with Scientists!
# Silver Medalist
